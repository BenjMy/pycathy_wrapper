# %% [markdown]
# # Weill et al notebook CATHY exemple
#
# The CATHY gitbucket repository provides the Weill et al. dataset example to test the installation. On top of that, we provide a computational notebook code to reproduce the results using the **pyCATHY wrapper** (https://github.com/BenjMy/pycathy_wrapper).
#
# The notebook illustrate how to work interactively: execute single cell, see partial results at different processing steps (preprocessing, processing, output)... You can share it to work collaboratively on it using the link and execute it from another PC without any installation required.

# %% [markdown]
# ## Step 0: package installation (not required if already installed)
#
# ---
#
# We first need to load the pyCATHY package. The pyCATHY package is calling fortran codes via python subroutines and ease the process

# %%
#%%capture
#!pip install git+https://github.com/BenjMy/pycathy_wrapper.git
#!pip install numpy GitPython pyvistaqt itkwidgets

# %%
# %%capture
from pyCATHY import cathy_tools
from pyCATHY.plotters import cathy_plots as cplt

# %%
#help(cathy_tools.CATHY)

# %% [markdown]
# **We initiate a CATHY object**;
# if the CATHY src files are not included within the 'path2prj' folder, they are automatically fetched from the gitbucket repository (providing the notebook is initiated with an internet connection).
#
#
#
# > Files are temporarily located by default in the 'my_cathy_prj' folder. We recommand to make a local backup copy of this folder or save it to the drive.
#
#
#
# > Calling `cathy_tools.CATHY` returns an python-object `simu` where all the parameters are accessible through a python dict

# %%
path2prj ='weil_exemple' # add your local path here
simu = cathy_tools.CATHY(dirName=path2prj,
                         clear_src=False, clear_outputs=True)
# Out:
# 🏁 Initiate CATHY object

# %% [markdown]
# # Step 1: preprocessing
#
# ---
# We run the **preprocessor** using the command `simu.run_preprocessor` with the default files inputs (weill et al example).
# This step create all the prepro files required for the processor later on.
#
#
# > If you need to change preprocessor parameters, pass the variable as an argument and change its value to update the corresponding file. For instance I want to ***change the resolution x to 0.1m*** of the DEM: ``` # simu.run_preprocessor(delta_x=0.1) ```

# %%
help(simu.run_preprocessor)
# Out:
# Help on method run_preprocessor in module pyCATHY.cathy_tools:
#
# run_preprocessor(KeepOutlet=True, verbose=False, **kwargs) method of pyCATHY.cathy_tools.CATHY instance
#     Run cppp.exe
#     1. updates cathy parameters prepo
#     2. recompile the source files prepo
#     3. run the preprocessor using bash cmd
#
#     Running the executable file has allowed to generate a complete set of
#     files describing physiographic features of the drainage system, as shown in Table 2.

# %%
# %%capture
simu.run_preprocessor(delta_x=0.2, verbose=False)
# Out:
# streamer.f90:62:71:
#
#    62 |   OPEN(UNIT=uni, FILE= fileName, ACTION= action, STATUS=status, ACCESS="transparent", IOSTAT=ii)   !##LF95##
#       |                                                                       1
# Warning: ACCESS specifier in OPEN statement at (1) has invalid value 'transparent'
# streamer.f90:62:71:
#
#    62 |   OPEN(UNIT=uni, FILE= fileName, ACTION= action, STATUS=status, ACCESS="transparent", IOSTAT=ii)   !##LF95##
#       |                                                                       1
# Warning: ACCESS specifier in OPEN statement at (1) has invalid value 'transparent'
# streamer.f90:62:71:
#
#    62 |   OPEN(UNIT=uni, FILE= fileName, ACTION= action, STATUS=status, ACCESS="transparent", IOSTAT=ii)   !##LF95##
#       |                                                                       1
# Warning: ACCESS specifier in OPEN statement at (1) has invalid value 'transparent'
# streamer.f90:62:71:
#
#    62 |   OPEN(UNIT=uni, FILE= fileName, ACTION= action, STATUS=status, ACCESS="transparent", IOSTAT=ii)   !##LF95##
#       |                                                                       1
# Warning: ACCESS specifier in OPEN statement at (1) has invalid value 'transparent'

# %%
#simu.update_prepo_inputs(show=True)

# %% [markdown]
# # Step 2: processing
# ---
#
#
# We run the **processor** with the default files inputs (weill et al example). This can last up to 3minutes

# %%
help(simu.run_processor)
# Out:
# Help on method run_processor in module pyCATHY.cathy_tools:
#
# run_processor(recompile=True, runProcess=True, verbose=False, **kwargs) method of pyCATHY.cathy_tools.CATHY instance
#     Run cathy.exe
#
#     1. updates cathy parameters and cathyH based on **kwargs
#     2. recompile the source files (set False for notebook) and create the executable
#     3. run the processor using bash cmd if runProcess is True
#
#     Parameters
#     ----------
#     recompile : TYPE, optional
#         DESCRIPTION. The default is True.
#     runProcess : TYPE, optional
#         DESCRIPTION. The default is True.
#     verbose : TYPE, optional
#         DESCRIPTION. The default is False.
#     **kwargs : TYPE
#         DESCRIPTION.

# %%
simu.run_processor(IPRT1=2,verbose=True)
# Out:
# ✒ update parm file
# key: IPRT1 | value: 2
# ✒ Update hap.in file
# adapt rivulet param to dem resolution
# dr
# 0.50
# ✒ update dem_parameters file
# 😔 cannot find existing dem paramters
# 0.50
# 0.50
# 1.0
# 1
# 0.002   0.004   0.006   0.008   0.01    0.01    0.02    0.02    0.05    0.05    0.1     0.1
# 0.2     0.2     0.22
# 🛠 Recompile src files
# chknew.f:23:72:
#
#    23 |       IF (N-2) 11,1,1
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:27:72:
#
#    27 |     1 IF(TOPOL(N+1)-1-NTERM) 12,2,12
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:37:72:
#
#    37 |          IF(IE-IS) 3,7,5
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:38:72:
#
#    38 |     3    IF(IE-IS+1) 13,4,24
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:47:72:
#
#    47 |             IF(JA(K+1)-JA(K)) 14,14,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:52:72:
#
#    52 |          IF(JA(K)-I)66,39,66
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:59:72:
#
#    59 |    39    IF(JS-1) 15,9,9
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:63:72:
#
#    63 |     9    IF(JE-N)10,10,16
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chknew.f:89:72:
#
#    89 |    20 IF(IER(1))22,23,22
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:23:72:
#
#    23 |       IF (N-2) 11,1,1
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:27:72:
#
#    27 |     1 IF(TOPOL(N+1)-1-NTERM) 12,2,12
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:37:72:
#
#    37 |          IF(IE-IS) 3,7,5
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:38:72:
#
#    38 |     3    IF(IE-IS+1) 13,4,24
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:47:72:
#
#    47 |             IF(JA(K+1)-JA(K)) 14,14,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:54:72:
#
#    54 |          IF(JS-I) 15,9,8
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:59:72:
#
#    59 |     9    IF(JE-N)10,10,16
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# chkpic.f:85:72:
#
#    85 |    20 IF(IER(1))22,23,22
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# strpic.f:55:72:
#
#    55 |     9          IF(I1(L)-JA(M))8,7,11
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# strpic.f:65:72:
#
#    65 |                IF(JA(MM))18,13,18
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# nudone.f:60:19:
#
#    59 |          DO J=2,NUDT
#       |                                                                        2
#    60 |             NUDTAU(J,I)=NUDTAU(1,1)
#       |                   1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# nudone.f:64:16:
#
#    63 |       DO J=2,NUDT
#       |                                                                        2
#    64 |          NUDTAU(J,1)=NUDTAU(1,1)
#       |                1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:142:72:
#
#   142 |          IF (IL-IH) 1,1,3
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:147:72:
#
#   147 |     2       SUM  =SUM-AUX*X(JCI)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 2 at (1)
# solscal-extended.f:148:72:
#
#   148 |     3    X(I2)=SUM*DI(I)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 3 at (1)
# solscal-extended.f:159:72:
#
#   159 |          IF (IL-IH) 4,4,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:164:72:
#
#   164 |     5       SUM  =SUM-AUX*X(JCI)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 5 at (1)
# solscal-extended.f:165:72:
#
#   165 |     6    X(I2)=SUM
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 6 at (1)
# solscal-extended.f:298:72:
#
#   298 |       IF (IER+12345) 2,1,2
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:322:72:
#
#   322 |     3       X(JCI)=0.D0
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 3 at (1)
# solscal-extended.f:329:72:
#
#   329 |     4       X(JAP)=A(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 4 at (1)
# solscal-extended.f:333:72:
#
#   333 |          IF (IL-IH) 5,5,9
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:343:72:
#
#   343 |             IF (JL-JH) 6,6,8
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:346:72:
#
#   346 |     7          X(JCI)=X(JCI)-XJI*C(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 7 at (1)
# solscal-extended.f:352:72:
#
#   352 |          IF (XD-FUZZ) 10,10,11
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:353:72:
#
#   353 |    10    IF (XD+FUZZ) 11,18,18
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:360:72:
#
#   360 |          IF (JL-IE) 12,12,14
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:366:72:
#
#   366 |    13       C(J) =XD*X(JCI)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 13 at (1)
# solscal-extended.f:389:72:
#
#   389 |       IF (IER+12345) 2,1,2
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:408:72:
#
#   408 |          IF (IAN) 35,35,3
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:418:72:
#
#   418 |     4       IX(K)=IPCI(JAP)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 4 at (1)
# solscal-extended.f:421:72:
#
#   421 |     5       IP(K)=K+1
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 5 at (1)
# solscal-extended.f:429:72:
#
#   429 |          IF (IX1-I) 7,22,37
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:435:72:
#
#   435 |          IF (IL-IH) 8,8,21
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:441:72:
#
#   441 |    10    IF (IX1-IC1) 11,13,15
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:452:72:
#
#   452 |          IF (IXP-1) 38,17,12
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:459:72:
#
#   459 |    13    IF (IL-IH) 14,21,38
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:474:72:
#
#   474 |          IF (IL-IH) 16,20,38
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:484:72:
#
#   484 |          IF (IL-IH) 18,19,38
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:507:72:
#
#   507 |          IF (INX+IN-IBOT) 24,24,23
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:513:72:
#
#   513 |    24    IF (IDC) 38,27,25
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:517:72:
#
#   517 |    26       IXPS =IP(IXPS)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 26 at (1)
# solscal-extended.f:520:72:
#
#   520 |          IF (IXPS-1) 38,29,28
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:575:72:
#
#   575 | 200   R(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 200 at (1)
# solscal-extended.f:584:72:
#
#   584 | 201   R(IA(K))=R(IA(K))+COEF1(K)*POTEN(JA(K))
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 201 at (1)
# solscal-extended.f:656:72:
#
#   656 | 520   POTEN(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 520 at (1)
# solscal-extended.f:687:72:
#
#   687 | 200   R(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 200 at (1)
# solscal-extended.f:776:72:
#
#   776 | 520   POTEN(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 520 at (1)
# solscal-extended.f:1286:72:
#
#  1286 | 200   R(K)=TNOTI(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 200 at (1)
# solscal-extended.f:1302:72:
#
#  1302 |       DO 205 M=I,J
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Shared DO termination label 205 at (1)
# solscal-extended.f:1327:72:
#
#  1327 | 302   B(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 302 at (1)
# solscal-extended.f:1331:72:
#
#  1331 |       DO 10 M=I,J
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Shared DO termination label 10 at (1)
# solscal-extended.f:1339:72:
#
#  1339 | 303   BB=BB+P(K)*B(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 303 at (1)
# solscal-extended.f:1343:72:
#
#  1343 | 304   POTEN(K)=POTEN(K)+ALFA*P(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 304 at (1)
# solscal-extended.f:1347:72:
#
#  1347 | 305   C=C+B(K)*scr(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 305 at (1)
# solscal-extended.f:1350:72:
#
#  1350 | 306   P(K)=scr(K)+BETA*P(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 306 at (1)
# solscal-extended.f:1403:72:
#
#  1403 | 200   R(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 200 at (1)
# solscal-extended.f:1412:72:
#
#  1412 | 201   R(IA(K))=R(IA(K))+COEF1(K)*POTEN(JA(K))
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 201 at (1)
# solscal-extended.f:1500:72:
#
#  1500 | 200   R(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 200 at (1)
# solscal-extended.f:1691:72:
#
#  1691 |  201          iw(jlu(i)) = 0
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 201 at (1)
# solscal-extended.f:2153:72:
#
#  2153 | 10    LRIGA(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# solscal-extended.f:2167:72:
#
#  2167 | 2     LRIGA(K1)=(COEFR(K1)-LRIGA(K1))/LRIGA(K)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 2 at (1)
# solscal-extended.f:2182:72:
#
#  2182 | 7     IF(JA(J1)-JA(I1))3,5,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2239:72:
#
#  2239 |       IF(JA(I)-JA(J)) 20,21,22
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2283:72:
#
#  2283 |       IF (N) 1,1,2
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2287:72:
#
#  2287 |     3    INP(J)=0
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 3 at (1)
# solscal-extended.f:2290:72:
#
#  2290 |          IF (IIP) 6,6,4
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2291:72:
#
#  2291 |     4    IF (N-IIP) 6,5,5
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2292:72:
#
#  2292 |     5    IF (INP(IIP)) 6,7,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2295:72:
#
#  2295 |     7    INP(IIP)=J
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 7 at (1)
# solscal-extended.f:2296:72:
#
#  2296 |       IF (IOPT-2) 11,8,11
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:2301:72:
#
#  2301 |     9    INP(IJ)=NJ
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 9 at (1)
# solscal-extended.f:2428:72:
#
#  2428 |  31           iw(i) = 0
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 31 at (1)
# solscal-extended.f:2479:72:
#
#  2479 |  201          iw(jlu(i)) = 0
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 201 at (1)
# solscal-extended.f:4097:72:
#
#  4097 | 45    Y(I)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 45 at (1)
# solscal-extended.f:4117:72:
#
#  4117 |       IF(JA(K)-IA(K))11,12,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4127:72:
#
#  4127 |       IF(IA(I)-JA(I)) 1,2,7
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4158:72:
#
#  4158 | 10    Y(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# solscal-extended.f:4176:72:
#
#  4176 | 10    X(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# solscal-extended.f:4180:72:
#
#  4180 |       DO 26 M=I,J
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Shared DO termination label 26 at (1)
# solscal-extended.f:4190:72:
#
#  4190 |       DO 27 M=I,J
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Shared DO termination label 27 at (1)
# solscal-extended.f:4215:72:
#
#  4215 |       IF(JA(K)-IA(K)) 11,12,6
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4239:72:
#
#  4239 |       IF(IA(I)-JA(I))1,2,7
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4478:72:
#
#  4478 |       IF (IER+12345) 2,1,2
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4481:72:
#
#  4481 |       IF (II) 4,4,3
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4482:72:
#
#  4482 |     3 IF (II-JJ) 5,4,4
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4496:72:
#
#  4496 |     6 IF (I-J) 7,19,19
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4512:72:
#
#  4512 |       IF (IA(I)-IT) 9,9,8
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4527:72:
#
#  4527 |       IF (IA(J)-IT) 10,13,13
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4540:72:
#
#  4540 |       IF (IA(I)-IT) 13,13,11
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4566:72:
#
#  4566 |       IF (IA(L)-IT) 14,14,13
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4573:72:
#
#  4573 |       IF (IA(K)-IT) 14,15,15
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4578:72:
#
#  4578 |    15 IF (K-L) 12,12,16
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4584:72:
#
#  4584 |    16 IF (L-I-J+K) 18,18,17
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4612:72:
#
#  4612 |       IF (M) 20,29,20
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4620:72:
#
#  4620 |    21 IF (J-I-11) 22,7,7
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4621:72:
#
#  4621 |    22 IF (I-II) 24,6,24
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4627:72:
#
#  4627 |    24 IF (I-J) 25,19,25
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4630:72:
#
#  4630 |       IF (IA(I)-IT) 23,23,26
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:4635:72:
#
#  4635 |       IF (IT-IA(K)) 27,28,28
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
# solscal-extended.f:5365:72:
#
#  5365 | 10    Y(K)=0.
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# solscal-extended.f:137:19:
#
#   133 |       DO 3 I=2,N
#       |                                                                        2
# ......
#   137 |          I1   =IPR(I)
#       |                   1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:138:19:
#
#   133 |       DO 3 I=2,N
#       |                                                                        2
# ......
#   138 |          I2   =IPC(I)
#       |                   1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:139:18:
#
#   133 |       DO 3 I=2,N
#       |                                                                        2
# ......
#   139 |          IL   =IC(I)
#       |                  1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:140:18:
#
#   133 |       DO 3 I=2,N
#       |                                                                        2
# ......
#   140 |          IH   =IU(I)-1
#       |                  1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:148:22:
#
#   133 |       DO 3 I=2,N
#       |                                                                        2
# ......
#   148 |     3    X(I2)=SUM*DI(I)
#       |                      1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:254:29:
#
#   253 |       DO 10 I=1,N
#       |                                                                        2
#   254 |       DO 20 J=TOPOL(I),TOPOL(I+1)-1
#       |                             1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:261:10:
#
#   253 |       DO 10 I=1,N
#       |                                                                        2
# ......
#   261 |       IAL(I+1)=I1
#       |          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:267:29:
#
#   266 |       DO 30 I=1,N
#       |                                                                        2
#   267 |       DO 40 J=TOPOL(I),TOPOL(I+1)-1
#       |                             1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:274:10:
#
#   266 |       DO 30 I=1,N
#       |                                                                        2
# ......
#   274 |       IAU(I+1)=I2
#       |          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:278:26:
#
#   277 |       DO 100 I=1,N
#       |                                                                        2
#   278 |       DO 200 J=IAU(I),IAU(I+1)-1
#       |                          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:307:18:
#
#   305 |       DO 14 I=1,N
#       |                                                                        2
#   306 |          IL   =IE+1
#   307 |          IE   =IC(I+1)-1
#       |                  1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:5385:13:
#
#  5384 |       DO 10 I=2,N
#       |                                                                        2
#  5385 |       IL=IAL(I)
#       |             1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:5388:13:
#
#  5384 |       DO 10 I=2,N
#       |                                                                        2
# ......
#  5388 |       NK=IAL(I+1)-IAL(I)-1
#       |             1
# Warning: Array reference at (1) out of bounds (3 > 1) in loop beginning at (2)
# solscal-extended.f:5388:22:
#
#  5384 |       DO 10 I=2,N
#       |                                                                        2
# ......
#  5388 |       NK=IAL(I+1)-IAL(I)-1
#       |                      1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:5395:8:
#
#  5384 |       DO 10 I=2,N
#       |                                                                        2
# ......
#  5395 |       X(I)=(B(I)-S)/DL(I)
#       |        1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:5395:14:
#
#  5384 |       DO 10 I=2,N
#       |                                                                        2
# ......
#  5395 |       X(I)=(B(I)-S)/DL(I)
#       |              1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:5395:23:
#
#  5384 |       DO 10 I=2,N
#       |                                                                        2
# ......
#  5395 |       X(I)=(B(I)-S)/DL(I)
#       |                       1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:5415:13:
#
#  5411 |       DO 60 I=N-1,1,-1
#       |                                                                        2
# ......
#  5415 |       NK=IAU(I+1)-1-IAU(I)
#       |             1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:4048:29:
#
#  4047 |       DO 10 I=1,N
#       |                                                                        2
#  4048 |       DO 20 J=TOPOL(I),TOPOL(I+1)-1
#       |                             1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:4055:10:
#
#  4047 |       DO 10 I=1,N
#       |                                                                        2
# ......
#  4055 |       IAL(I+1)=I1
#       |          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:4061:29:
#
#  4060 |       DO 30 I=1,N
#       |                                                                        2
#  4061 |       DO 40 J=TOPOL(I),TOPOL(I+1)-1
#       |                             1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:4068:10:
#
#  4060 |       DO 30 I=1,N
#       |                                                                        2
# ......
#  4068 |       IAU(I+1)=I2
#       |          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:4072:26:
#
#  4071 |       DO 100 I=1,N
#       |                                                                        2
#  4072 |       DO 200 J=IAU(I),IAU(I+1)-1
#       |                          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# solscal-extended.f:4078:26:
#
#  4077 |       DO 300 I=1,N
#       |                                                                        2
#  4078 |       DO 400 J=IAL(I),IAL(I+1)-1
#       |                          1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# cathy_main.f:2935:19:
#
#  2934 |             DO I=1,NR
#       |                                                                        2
#  2935 |                RWU(I)=0.0d0
#       |                   1
# Warning: Array reference at (1) out of bounds (1 > 0) in loop beginning at (2)
# cathy_main.f:2937:22:
#
#  2934 |             DO I=1,NR
#       |                                                                        2
# ......
#  2937 |                   RWU(I)=RWU(I)+QTRANIE((J-1)*NNOD+CONTR(I))
#       |                      1
# Warning: Array reference at (1) out of bounds (1 > 0) in loop beginning at (2)
# cathy_main.f:2937:29:
#
#  2934 |             DO I=1,NR
#       |                                                                        2
# ......
#  2937 |                   RWU(I)=RWU(I)+QTRANIE((J-1)*NNOD+CONTR(I))
#       |                             1
# Warning: Array reference at (1) out of bounds (1 > 0) in loop beginning at (2)
# cathy_main.f:2937:57:
#
#  2934 |             DO I=1,NR
#       |                                                                        2
# ......
#  2937 |                   RWU(I)=RWU(I)+QTRANIE((J-1)*NNOD+CONTR(I))
#       |                                                         1
# Warning: Array reference at (1) out of bounds (1 > 0) in loop beginning at (2)
# cathy_main.f:2940:40-50:
#
#  2940 |             WRITE(666,*)TIME,QTRAN,(RWU(I),I=1,NR)
#       |                                        1         2
# Warning: Array reference at (1) out of bounds (1 > 0) in loop beginning at (2)
# strnew.f:47:72:
#
#    47 |     9          IF(I1(L)-JA(M))8,7,11
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: Arithmetic IF statement at (1)
-08
#  CONVERGENCE ACHIEVED IN    2 ITERATIONS
#
#
#       TIME STEP:      531    DELTAT:   1.0000E+01    TIME:   3.5854E+03
#      ******************************************************************
#
#
#                      NONLINEAR CONVERGENCE BEHAVIOR
#  iter- convergence error norms  node    PNEW at    POLD at  residual error norms
#  ation         PL2      PIKMAX IKMAX      IKMAX      IKMAX        FL2       FINF
#      1  9.0116E-03 -3.2145E-04  3092  -4.61E-02  -4.58E-02  7.100E-06  1.075E-06
#      2  3.7097E-04 -5.3232E-05  3970   1.27E-01   1.27E-01  2.125E-07  4.923E-08
#  CONVERGENCE ACHIEVED IN    2 ITERATIONS
#
#
#       TIME STEP:      532    DELTAT:   7.2823E+00    TIME:   3.5927E+03
#      ******************************************************************
#
#
#                      NONLINEAR CONVERGENCE BEHAVIOR
#  iter- convergence error norms  node    PNEW at    POLD at  residual error norms
#  ation         PL2      PIKMAX IKMAX      IKMAX      IKMAX        FL2       FINF
#      1  6.7123E-03  6.7953E-04   344  -3.00E-04  -9.80E-04  7.098E-06  1.072E-06
#      2  9.7325E-04 -6.7420E-05   882   1.25E-02   1.26E-02  1.749E-06  4.179E-07
#  CONVERGENCE ACHIEVED IN    2 ITERATIONS
#
#
#       TIME STEP:      533    DELTAT:   7.2823E+00    TIME:   3.6000E+03
#      ******************************************************************
#
#
#                      NONLINEAR CONVERGENCE BEHAVIOR
#  iter- convergence error norms  node    PNEW at    POLD at  residual error norms
#  ation         PL2      PIKMAX IKMAX      IKMAX      IKMAX        FL2       FINF
#      1  6.5476E-03 -2.3438E-04  3092  -4.66E-02  -4.64E-02  7.092E-06  1.069E-06
#      2  3.0323E-04 -4.1483E-05  3220   5.90E-02   5.91E-02  1.744E-07  5.478E-08
#  CONVERGENCE ACHIEVED IN    2 ITERATIONS

# %% [markdown]
# # Visualisation
# ---
# Plot the results (for now using pyvista for 3d visualisation, need to update some dependencies before plotting)

# %%
# %%capture
#!apt-get install -qq xvfb
#!pip install pyvista panel -q
import os
#os.system('/usr/bin/Xvfb :99 -screen 0 1024x768x24 &')
#os.environ['DISPLAY'] = ':99'
#import panel as pn
#pn.extension('vtk')

# %%
help(cplt.show_vtk)
#print(os.getcwd())
# Out:
# Help on function show_vtk in module pyCATHY.plotters.cathy_plots:
#
# show_vtk(filename=None, unit='pressure', timeStep=0, notebook=False, path=None, savefig=False, **kwargs)
#     Plot vtk file using pyvista
#     Parameters
#     ----------
#     filename : TYPE, optional
#         DESCRIPTION. The default is None.
#     unit : str, optional
#         ['pressure', 'saturation', 'ER', 'permeability', 'velocity'] . The default is pressure.
#     timeStep : TYPE, optional
#         DESCRIPTION. The default is 0.
#     notebook : TYPE, optional
#         DESCRIPTION. The default is False.
#     path : TYPE, optional
#         DESCRIPTION. The default is None.
#     savefig : TYPE, optional
#         DESCRIPTION. The default is False.
#     **kwargs : TYPE
#         DESCRIPTION.
#
#     Returns
#     -------
#     None.

# %%
cplt.show_vtk(unit='pressure',
              timeStep=1,
              notebook=True, 
              path='./my_cathy_prj/vtk/'
             )
# Out:
# plot pressure
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_267451/10749390.py in <module>
# ----> 1 cplt.show_vtk(unit='pressure',
#       2               timeStep=1,
#       3               notebook=True,
#       4               path='./my_cathy_prj/vtk/'
#       5              )
#
# ~/Documents/GitHub/BenjMy/pycathy_wrapper/lib/pyCATHY/plotters/cathy_plots.py in show_vtk(filename, unit, timeStep, notebook, path, savefig, **kwargs)
#     308
#     309         print('figure saved' + os.path.join(path,filename + '.svg'))
# --> 310     cpos = plotter.show()
#     311
#     312     return
#
# UnboundLocalError: local variable 'plotter' referenced before assignment
