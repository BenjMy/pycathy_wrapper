# %%
# %matplotlib inline

# %% [markdown]
# # Weil et al example

# %%
# In[2]:

from pyCATHY import cathy_tools
from pyCATHY.plotters import cathy_plots as cplt

# In[13]:


path2prj ='weil_exemple' # add your local path here
simu = cathy_tools.CATHY(dirName=path2prj)
simu.run_processor(IPRT1=2,verbose=True)

cplt.show_vtk(unit='pressure',
              timeStep=1,
              notebook=False, 
              path='./my_cathy_prj/vtk/'
             )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_281455/3120363076.py in <module>
#       1 # In[2]:
#       2
# ----> 3 from pyCATHY import cathy_tools
#       4 from pyCATHY.plotters import cathy_plots as cplt
#       5
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/pyCATHY/__init__.py in <module>
# ----> 1 from pyCATHY.plotters import cathy_plots
#       2 from pyCATHY.DA import cathy_DA
#       3
#       4
#       5
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/pyCATHY/plotters/cathy_plots.py in <module>
#      27
#      28 from pyCATHY.importers import cathy_outputs as out_CT
# ---> 29 from pyCATHY.cathy_utils import (label_units,
#      30                                  transform2_time_delta,
#      31                                  convert_time_units,
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/pyCATHY/cathy_utils.py in <module>
#      16 import pandas as pd
#      17 from datetime import datetime, timedelta
# ---> 18 from rosetta import rosetta, SoilData
#      19 import numpy as np
#      20 from pyCATHY.plotters import cathy_plots as pltCT
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/rosetta/__init__.py in <module>
# ----> 1 from rosetta.text.api import *
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/rosetta/text/api.py in <module>
# ----> 1 from rosetta.text.streamers import TextFileStreamer
#       2
#       3 from rosetta.text.text_processors import \
#       4     TokenizerBasic, MakeTokenizer, SFileFilter, VWFormatter
#       5
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/rosetta/text/streamers.py in <module>
#      15 from .. import common
#      16 from ..common import lazyprop, smart_open, DocIDError
# ---> 17 from . import filefilter, text_processors
#      18
#      19
#
# ~/miniconda3/envs/pyCATHY/lib/python3.9/site-packages/rosetta/text/text_processors.py in <module>
#      22 import math
#      23
# ---> 24 import nltk
#      25 import numpy as np
#      26 import pandas as pd
#
# ModuleNotFoundError: No module named 'nltk'
